# %% [markdown]
# <a href="https://colab.research.google.com/github/mralamdari/Machine_Learning_Projects/blob/main/Language_Detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import nltk
import pandas as pd

# %%
file_path_csv = '/content/drive/MyDrive/University/dataMining.csv'
file_path_txt = '/content/drive/MyDrive/University/dataMining.txt'
os.replace(file_path_csv, file_path_txt)

# %%
pd.read_csv(file_path_txt)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-53-b0e7dfaf8997> in <module>
# ----> 1 pd.read_csv(file_path_txt)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
s = ' Ejemplos de uso de la minería de datos  [editar]El ejemplo clásico aparte de algo rancio y posiblemente apócrifospanish'
a = ' Un estudio muy citado detectó que los viernes había una cantidad inusualmente elevada de clientes que adquirían a la vez pañales y cerveza.'

# %%
with open('/content/sample_data/kkkk.txt', 'r') as f:
  print(f.readlines())
# Out:
# ['class,content,\n', "english,'Data mining has been defined as the nontrivial extraction of implicit previously unknown and potentially useful information from data and the science of extracting useful information from large data sets or databases.',\n", "english,'An example of data mining often called the Market Basket Analysis relates to its use in retail sales.',\n", "english,'If a clothing store records the purchases of customers a data mining system could identify those customers who favour silk shirts over cotton ones. Although some explanations of relationships may be difficult taking advantage of it is easier. ',\n", "english,'The example deals with association rules within transaction-based data.',\n", "english,'Not all data is transaction based and logical or inexact rules may also be present within a database.',\n", "english,'In a manufacturing application an inexact rule may state that 73\\% of products which have a specific defect or problem will develop a secondary prob
# ...

# %%
with open('/content/drive/MyDrive/University/dataMining.txt', 'r') as f:
  print(f.readlines())
# Out:
# ['class,content\n', "english,'Data mining has been defined as the nontrivial extraction of implicit previously unknown and potentially useful information from data and the science of extracting useful information from large data sets or databases.'\n", "english,'An example of data mining often called the Market Basket Analysis relates to its use in retail sales.'\n", "english,'If a clothing store records the purchases of customers a data mining system could identify those customers who favour silk shirts over cotton ones. Although some explanations of relationships may be difficult taking advantage of it is easier. '\n", "english,'The example deals with association rules within transaction-based data.'\n", "english,'Not all data is transaction based and logical or inexact rules may also be present within a database.'\n", "english,'In a manufacturing application an inexact rule may state that 73\\% of products which have a specific defect or problem will develop a secondary problem wi
# ...

# %%
with open(file_path_txt, 'r') as f:
  print(f.readlines())
# Out:
# ['class,content\n', "english,'Data mining has been defined as the nontrivial extraction of implicit previously unknown and potentially useful information from data and the science of extracting useful information from large data sets or databases.'\n", "english,'An example of data mining often called the Market Basket Analysis relates to its use in retail sales.'\n", "english,'If a clothing store records the purchases of customers a data mining system could identify those customers who favour silk shirts over cotton ones. Although some explanations of relationships may be difficult taking advantage of it is easier. '\n", "english,'The example deals with association rules within transaction-based data.'\n", "english,'Not all data is transaction based and logical or inexact rules may also be present within a database.'\n", "english,'In a manufacturing application an inexact rule may state that 73\\% of products which have a specific defect or problem will develop a secondary problem wi
# ...

# %%
pd.read_csv('/content/sample_data/anscombe.txt')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-56-0ebeccc5fa07> in <module>
# ----> 1 pd.read_csv('/content/sample_data/anscombe.txt')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
